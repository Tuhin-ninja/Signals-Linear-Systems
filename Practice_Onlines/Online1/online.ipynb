# %%
import import_ipynb
import Discrete

# %%
degree1 = int(input("Degree of the first polynomial: "))
input_signal = Discrete.DiscreteSignal(7)
coeff1 = []
for i in range(degree1+1):
    print(i)
    # print("Enter the coefficient of x^", i)
    # coeff1.append(float(input()))
    input_signal.set_value_at_time(i, float(input("Enter the coefficient of x^"+str(-i+degree1)+": ")))

# input_signal = input_signal.shift_signal(2)
input_signal.plot("input signal")

degree2 = int(input("Degree of the second polynomial: "))
impulse_response = Discrete.DiscreteSignal(7)
# input("Coefficients : ")
# coeff2 = []
for i in range(degree2+1):
    impulse_response.set_value_at_time(i, float(input()))
impulse_response.plot("impulse response")

lti_system = Discrete.LTI_Discrete(impulse_response)
# lti_system.response_of_input_plot(input_signal)
out,cons,x = lti_system.output(input_signal)
out.plot("final")
print(out.values)

#
# Out:
# 0
# 1
# 2
# Plot saved as Discrete/input signal.png
# Plot saved as Discrete/impulse response.png
# Plot saved as Discrete/final.png
# [ 0.  0.  0.  0.  0.  0.  0.  2.  3. -4.  4.  8.  1. -2.  0.]
